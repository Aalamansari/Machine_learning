# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv('dm_office_sales.csv')

# %%
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
#Create the rugplot
sns.rugplot(x='salary',data=df)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
#Change the height of the rug plot
sns.rugplot(x='salary',data=df,height=0.5)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
sns.displot(data=df,x="salary")

# %%
#More the number of bins more the plot will be detailed
sns.displot(data=df,x="salary",bins=50)

# %%
sns.set(style='darkgrid')
sns.displot(data=df,x="salary",bins=50)

# %%
sns.set(style='whitegrid')
sns.displot(data=df,x="salary",bins=50)

# %%
sns.set(style='dark')
sns.displot(data=df,x="salary",bins=50)

# %%
sns.set(style='white')
sns.displot(data=df,x="salary",bins=50)

# %%
sns.set(style='ticks')
sns.displot(data=df,x="salary",bins=50)

# %%
# Once the sns style is set then it will remain same until a new style is implemented
sns.displot(data=df,x="salary",bins=50)

# %%
sns.displot(data=df,x="salary",bins=50,color='red',ls='--')

# %%
sns.histplot(data=df,x='salary')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %% [markdown]
# ## hisplot is just a generalised form of the displot

# %%
# Make the kde curve
sns.displot(data=df,x="salary",bins=30,kde=True)

# %%
# Make the kde curve and rug visible
sns.displot(data=df,x="salary",bins=30,kde=True,rug=True)

# %%
# IF u only wanna see the kde plot then use kdeplot()
sns.kdeplot(data=df,x='salary')
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
np.random.seed(40)
sample_ages = np.random.randint(0,100,220)

# %%
sample_ages
# Out:
# array([70, 91,  7, 37, 56, 50, 65, 12, 71, 19, 31, 74, 55, 83, 59, 91, 73,
#        96, 49, 53, 73,  8, 52, 30, 79, 14, 92, 58, 74, 22,  3, 91, 99, 71,
#        55, 83, 28, 13, 37, 82, 50, 79, 67, 30, 60, 44, 46, 87, 43, 35, 98,
#        31, 82,  5, 80, 65,  7, 92, 41, 99, 95, 88, 93, 25, 83, 58, 98, 70,
#        57, 57, 83, 85, 36, 63, 74, 88,  0,  1, 33, 52, 72, 57, 34, 14, 78,
#        71, 56, 77, 86, 84, 82, 91, 12, 90, 73, 27,  0, 21, 94, 32, 51, 50,
#        20, 41, 78, 55, 47, 43, 91, 76, 29, 45,  7, 10, 61, 19, 68, 25, 61,
#        98, 16, 88, 61, 51, 88, 41, 58, 21, 31, 95, 43, 68, 16,  3, 15, 79,
#         4,  6, 94, 66, 85, 51, 90, 83,  2,  9,  6, 39, 25, 56, 17, 13,  7,
#        50, 96, 48, 53,  0, 38, 60, 48, 67, 97, 61, 45, 61, 10, 77, 57, 52,
#        40,  1, 52, 58, 88, 22, 48, 24, 58, 93, 74, 89, 96, 43, 64, 71,  6,
#        43, 36, 77, 96,  2, 64, 75, 79, 94, 10, 15, 97, 20, 83, 82, 81, 28,
#        83, 21, 27, 36, 91, 81, 15, 38, 85, 60, 17, 95, 56,  7, 63, 55])

# %%
sample_ages = pd.DataFrame(sample_ages,columns=['ages'])

# %%
sample_ages
# Out:
#      ages
# 0      70
# 1      91
# 2       7
# 3      37
# 4      56
# ..    ...
# 215    95
# 216    56
# 217     7
# 218    63
# 219    55
#
# [220 rows x 1 columns]

# %%
sns.rugplot(data=sample_ages,x='ages')
# Out:
# <AxesSubplot:xlabel='ages'>

# %%
sns.displot(data=sample_ages,x='ages',rug=True,bins=30,kde=True)

# %%
# To cutoff the overflowing kde curve outside the range we use clip
sns.kdeplot(data=sample_ages,x='ages',clip=[0,100])
# Out:
# <AxesSubplot:xlabel='ages', ylabel='Density'>

# %%
# We can change the bandwidth of the kde curve with the bw_adjust
sns.kdeplot(data=sample_ages,x='ages',clip=[0,100],bw_adjust=0.2)
# Larger the bw_adjust value higher the normalization
# Out:
# <AxesSubplot:xlabel='ages', ylabel='Density'>

# %%
# We can shade the area under the kde curve using shade
sns.kdeplot(data=sample_ages,x='ages',clip=[0,100],bw_adjust=0.2,shade=True)
# Out:
# <AxesSubplot:xlabel='ages', ylabel='Density'>
