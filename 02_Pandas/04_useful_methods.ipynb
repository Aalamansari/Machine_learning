# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# While pandas has many built In methods,
# we can use the .apply() method call to
# apply any custom python function of our
# own to every row in a Series.

# %% [markdown]
# We can use either one or multiple columns
# as input, let's explore this in the notebook!

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#To get the last four digits of the CC Number column
str(3560325168603410)[-4:]
# Out:
# '3410'

# %%
# We can define a function that works the same as the above code

# %%
def last_four(num):
    return str(num)[-4:]

# %%
last_four(3560325168603410)
# Out:
# '3410'

# %%
df['last_four']=df['CC Number'].apply(last_four)

# %% [markdown]
# The above line applies last_four() function to all the values of CC Number column

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four
# ...

# %%
df['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
def any(price):
    if price < 10:
        return '$'
    elif price >= 10 and price < 30:
        return '$$'
    else:
        return '$$$'

# %%
df['any'] = df['total_bill'].apply(any)

# %%
df['any']
# Out:
# 0      $$
# 1      $$
# 2      $$
# 3      $$
# 4      $$
#        ..
# 239    $$
# 240    $$
# 241    $$
# 242    $$
# 243    $$
# Name: any, Length: 244, dtype: object

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID last_four any
# ...

# %% [markdown]
# ## The functions in the apply method must return only a single value not a series

# %%
# def simple(num):
#     return num*2
# The above function can be written using lamda
# lambda num: num*2

# %% [markdown]
# ## The lamba cannot be used for complex expressions

# %%
df['total_bill'].apply(lambda bill: bill*2)
# Out:
# 0      33.98
# 1      20.68
# 2      42.02
# 3      47.36
# 4      49.18
#        ...
# 239    58.06
# 240    54.36
# 241    45.34
# 242    35.64
# 243    37.56
# Name: total_bill, Length: 244, dtype: float64

# %%
def quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return "Generous "
    else:
        return "Other"

# %%
quality(16.99,1.01)
# Out:
# 'Other'

# %%
 df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)
# Out:
# 0      Other
# 1      Other
# 2      Other
# 3      Other
# 4      Other
#        ...
# 239    Other
# 240    Other
# 241    Other
# 242    Other
# 243    Other
# Length: 244, dtype: object

# %% [markdown]
# 1. Select the columns on which you want to apply
# 2. define the dataframe name eg. df:
# 3. define function and pass the parameters

# %%
 df['quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
# ...

# %% [markdown]
# Another method to apply a complex function to multiple columns

# %%
df['Quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID last_four any quality  \
# 0  Christy Cunningham  3560325168603410    Sun2959      3410  $$   Other
# 1      Douglas Tucker  4478071379779230    Sun4608      9230  $$   Other
# 2      Travis Walters  6011812112971322    Sun4458      1322  $$   Other
# 3    Nathaniel Harris  4676137647685994    Sun5260      5994  $$   Other
# 4        Tonya Carter  4832732618637221    Sun2251      7221  $$   Other
#
#   Quality
# 0   Other
# 1   Other
# 2   Other
# 3   Other
# 4   Other

# %% [markdown]
# ## Check the time taken by both the methods using the timeit module

# %%
import timeit

# %%
 # code snippet to be executed only once
setup =  '''
import numpy as np
import pandas as pd
df = pd.read_csv('tips.csv')
 def quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "Other"
 '''

# %%
#Code snippet whose execution time is to be measured

stmt_one ='''
df['Tip Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1) 
'''
stmt_two = '''
df['Tip Quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])
'''

# %%
timeit.timeit(setup=setup,stmt=stmt_one,number=1000)
# Out:
# 3.884237600000006

# %%
timeit.timeit(setup=setup,stmt=stmt_two,number=1000)
# Out:
# 0.24784980000003998

# %%
df = pd.read_csv('tips.csv')

# %%
df.sort_values('tip')
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#To sort the column in the descending order

# %%
df.sort_values('tip',ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ## Sort multiple columns

# %%
df.sort_values(['tip','size'])
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
#
#              Payer Name         CC Number Payment ID
# ...

# %% [markdown]
# ### How to grab the index locations of the min and max values

# %%
#Grab the max value
df['total_bill'].max()
# Out:
# 50.81

# %%
# Grab the index of the max value
df['total_bill'].idxmax()
# Out:
# 170

# %%
#Grab the information of the value using its index
df.iloc[170]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
#Grab the min value
df['total_bill'].min()
# Out:
# 3.07

# %%
# Grab the index of the min value
df['total_bill'].idxmin()
# Out:
# 67

# %%
#Grab the information of the value using its index
df.iloc[67]
# Out:
# total_bill                      3.07
# tip                              1.0
# sex                           Female
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               1
# price_per_person                3.07
# Payer Name             Tiffany Brock
# CC Number           4359488526995267
# Payment ID                   Sat3455
# Name: 67, dtype: object

# %% [markdown]
# ### To check the correlation between the values of different columns

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %% [markdown]
# ### To check the count of categorical values

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %% [markdown]
# ### To get the unique values in the column

# %%
df['day'].unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %% [markdown]
# ### To get the count of unique values in the column

# %%
df['day'].nunique()
# Out:
# 4

# %% [markdown]
# ### Replace a single value of the column

# %%
df['sex'].replace('Female','F')
# Out:
# 0         F
# 1      Male
# 2      Male
# 3      Male
# 4         F
#        ...
# 239    Male
# 240       F
# 241    Male
# 242    Male
# 243       F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# ### Replace multiple value of the column

# %%
df['sex'].replace(['Female','Male'],['F','M'])
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# ### Another method to replace values in the column

# %%
mymap = {'Female':'F','Male':'M'}

# %%
df['sex'].map(mymap)
# Out:
# 0      F
# 1      M
# 2      M
# 3      M
# 4      F
#       ..
# 239    M
# 240    F
# 241    M
# 242    M
# 243    F
# Name: sex, Length: 244, dtype: object

# %% [markdown]
# ### To check the duplications in the columns

# %%
simple_df = pd.DataFrame([1,2,2],['a','b','c'])

# %%
simple_df
# Out:
#    0
# a  1
# b  2
# c  2

# %%
simple_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# dtype: bool

# %%
#To drop the duplicates 
simple_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %% [markdown]
# ### To check if the values are inclusive betweem two values

# %%
df['total_bill'].between(10,20,inclusive=True)
# Out:
# C:\Users\aalam\AppData\Local\Temp\ipykernel_23200\4013148072.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df['total_bill'].between(10,20,inclusive=True)
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242     True
# 243     True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df['total_bill'].between(10,20,inclusive=True)]
# Out:
# C:\Users\aalam\AppData\Local\Temp\ipykernel_23200\1152120679.py:1: FutureWarning: Boolean inputs to the `inclusive` argument are deprecated in favour of `both` or `neither`.
#   df[df['total_bill'].between(10,20,inclusive=True)]
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 8         15.04  1.96    Male     No   Sun  Dinner     2              7.52
# 9         14.78  3.23    Male     No   Sun  Dinner     2              7.39
# 10        10.27  1.71    Male     No   Sun  Dinner     2              5.14
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25    Male     No   Sat  Dinner     2              5.04
# ...

# %% [markdown]
# ### To get the n largest values from the columns

# %%
df.nlargest(2,'tip')
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0  Male    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0  Male     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590

# %% [markdown]
# # To get the n smallest values from the columns

# %%
df.nsmallest(2,'tip')
# Out:
#     total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67        3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 92        5.75  1.0  Female    Yes  Fri  Dinner     2              2.88
#
#        Payer Name         CC Number Payment ID
# 67  Tiffany Brock  4359488526995267    Sat3455
# 92   Leah Ramirez  3508911676966392    Fri3780

# %%
df.sort_values('tip',ascending=True).iloc[0:2]
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 67         3.07  1.0  Female    Yes  Sat  Dinner     1              3.07
# 236       12.60  1.0    Male    Yes  Sat  Dinner     2              6.30
#
#         Payer Name         CC Number Payment ID
# 67   Tiffany Brock  4359488526995267    Sat3455
# 236  Matthew Myers  3543676378973965    Sat5032

# %%
#To get the sample random rows from the dataframe
df.sample(4)
# Out:
#      total_bill  tip     sex smoker  day    time  size  price_per_person  \
# 186       20.90  3.5  Female    Yes  Sun  Dinner     3              6.97
# 44        30.40  5.6    Male     No  Sun  Dinner     4              7.60
# 49        18.04  3.0    Male     No  Sun  Dinner     2              9.02
# 220       12.16  2.2    Male    Yes  Fri   Lunch     2              6.08
#
#          Payer Name         CC Number Payment ID
# 186  Heidi Atkinson  4422858423131187    Sun4254
# 44      Todd Cooper      503846761263    Sun2274
# 49     William Roth  6573923967142503    Sun9774
# 220   Ricky Johnson   213109508670736    Fri4607

# %%
df.sample(frac=0.1)
#The above code will give 10% of the rows of the dataframe
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 154       19.77   2.00    Male     No   Sun  Dinner     4              4.94
# 216       28.15   3.00    Male    Yes   Sat  Dinner     5              5.63
# 135        8.51   1.25  Female     No  Thur   Lunch     2              4.26
# 178        9.60   4.00  Female    Yes   Sun  Dinner     2              4.80
# 110       14.00   3.00    Male     No   Sat  Dinner     2              7.00
# 177       14.48   2.00    Male    Yes   Sun  Dinner     2              7.24
# 238       35.83   4.67  Female     No   Sat  Dinner     3             11.94
# 17        16.29   3.71    Male     No   Sun  Dinner     3              5.43
# 179       34.63   3.55    Male    Yes   Sun  Dinner     2             17.32
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 125       29.80   4.20  Female     No  Thur   Lunch     6              4.97
# ...
